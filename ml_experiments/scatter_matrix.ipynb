# %% [markdown]
# # Scatterplot matrix

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
d = pd.read_csv('rh_data.csv')
print('Columns:',list(d.columns))
sns.pairplot(d.iloc[:,1:], hue='gender'); # Don't include id into this, of course
# Out:
# Columns: ['id', 'work', 'gender', 'age', 'treatment', 'before', 'after']
