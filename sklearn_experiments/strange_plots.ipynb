# %% [markdown]
# # Strange plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def cil(x0=0, y0=0, r=1, z=(0,1), c='red', arc=None):
    if arc is None: arc = [0, 2]
    n = 100
    t = np.linspace(arc[0], arc[1], n)*np.pi
    x = np.cos(t)
    y = np.sin(t)
    if arc[1]-arc[0]<2:
        x = np.hstack((x, [0]))
        y = np.hstack((y, [0]))
        n = n+1
    x = np.repeat(np.atleast_2d(x),2, axis=0)*r + x0
    y = np.repeat(np.atleast_2d(y),2, axis=0)*r + y0
    z = np.vstack((np.zeros(shape=(1,n)), np.ones(shape=(1,n))))*(z[1]-z[0]) + z[0]
    ax.plot_surface(x,y,z, color=c, alpha=0.5)
    
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.xaxis.set_pane_color([1,1,1,0])
ax.yaxis.set_pane_color([1,1,1,0])
ax.zaxis.set_pane_color([1,1,1,0])
ax.grid(False)
col = ['red', 'yellow', 'cyan']
for i in range(20):
    x = np.random.uniform(size=2)
    r = np.random.uniform()/5/(np.sqrt(i)+1)
    z = np.cumsum(np.hstack((np.random.uniform(), np.random.uniform(size=3)/(np.sqrt(i)+1))))
    for j in range(3):
        cil(x[0], x[1], r, tuple(z[j:j+2]), col[j])
    cil(x[0], x[1], r, (z[-1], z[-1]+0.1), 'violet', [2, 0.7])
