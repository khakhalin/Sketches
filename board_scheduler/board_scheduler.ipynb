# %% [markdown]
# ## Sproj Board Scheduler
#
# An attempt to write a script that would read faculty and students availability for the boards week, and then schedule all boards, accounting for their target composition, and student availability.
#
# Unfortunately some of the data used by this script (names) is sensitive, and had to be stored outside of git.

# %%
import pandas as pd
import time
import copy
import random

# %%
hideNames = 1 # set 0 for troubleshooting, set 1 before githubbing

# %%
composition = pd.read_csv('../../sensitive_data/boards.csv')
students = pd.read_csv('../../sensitive_data/students.csv')
facultin = pd.read_csv('../../sensitive_data/faculty.csv')

# %%
# Create time grid
days = ['m','t','w','r','f']
dayName = {'m':'Mon','t':'Tue','w':'Wed','r':'Thu','f':'Fri'}

startTime = 9
endTime = 18
grid = [] # Array of tuples: day (as a letter), hour (as a 24h int number)
for d in days:
    for t in range(startTime,endTime):
        grid = grid + [(d,t)]
print(grid[:3])

facultin.time = facultin.time.apply(lambda x: max(x,startTime))
# Note that the script doesn't check times outside of start-end window, so all ins and outs should happen either
# within this window, or before the day starts (to add or remove an entire day)
# Out:
# [('m', 9), ('m', 10), ('m', 11)]

# %%
class Faculty:
    def __init__(self,name):
        self.name = name
        self.avail = []
        
    def __str__(self):
        return "%12s \t" % (self.name) + ''.join(['%d' % i for i in self.avail])
    
    def initAvail(self,grid,facultin):
        self.avail = [1]*len(grid)
        status = 1
        for ig in range(len(grid)):
            lin = facultin.loc[(facultin['name']==self.name) & 
                               (facultin['type']=='in') & 
                               (facultin['day']==grid[ig][0]) &
                               (facultin['time']==grid[ig][1])]
            if lin.shape[0]>0:
                status = 1
            lout = facultin.loc[(facultin['name']==self.name) & 
                               (facultin['type']=='out') & 
                               (facultin['day']==grid[ig][0]) &
                               (facultin['time']==grid[ig][1])]
            if lout.shape[0]>0:
                status = 0
            self.avail[ig] = status
            
    def updateAvail(self,grid,g):
        self.avail = [self.avail[i] if grid[i]!=g else 0 for i in range(len(self.avail))]
        
    def book(self,ig):
        self.avail[ig] = 0
        
        
faculty = []
for fn in composition['advisor'].append(composition['mem2']).append(composition['mem3']).unique():
    f = Faculty(fn)
    f.initAvail(grid,facultin)
    for d in days:
        f.updateAvail(grid,(d,12)) # Book lunch breaks
    faculty.append(f)    

for f in faculty:
    print(f)
# Out:
#         Jude 	111011111111011111111011111000011111111011111
#     Tibbetts 	000000000111011111000000000111011111111011111
#    Robertson 	111011111111011111111011111111011111111011111
#      Collins 	111011111111011111111011111111011111111011111
#      Keesing 	111011111111011111000000000000000000000000000
#    Khakhalin 	111011111111011111111011111111011111111011111
#       Perron 	111011111111011111111011111111011111111011111
#      Bennett 	111011111111011111111011111111011111111011111
#       Dueker 	111011111111011111111011111111011111111011111
#     Keesing  	111011111111011111111011111111011111111011111
#         Jain 	111011111111011111111011111111011111111011111
#       Scalzo 	111011111111011111111011111111011111111011111

# %%
class Board:
    '''Board object'''
    
    def __init__(self,stuff): # Creator
        self.student = stuff['first'] + ' ' + stuff['last']
        if hideNames:
            self.student = ''.join(random.sample(self.student,len(self.student)))
        self.members = list(stuff[['advisor','mem2','mem3']])
        self.email = stuff['email']
        self.type = stuff['type']
        self.avail = []  # Placeholder: availability grid
        self.time = []
        
    def __str__(self):
        s = "%25s" % (self.student) + '\t' 
        s += ' '.join([m[:4] for m in self.members]) + '\t' # Shortened version
        s += ''.join(['%d' % i for i in self.avail])
        return s
    
    def initTimes(self,grid,students):
        '''Sets boards initial options, based on students availability'''
        data = students.loc[students.email==self.email]
        self.avail = [1]*len(grid)
        for i in range(data.shape[0]):
            if data.iloc[i]['class'][:3]=='BIO':
                continue # Ignore bio classes
            for d in days:
                if not pd.isna(data.iloc[i][d]): # Class meets on this day
                    times = data.iloc[i]['time'].split('-') # String of two times
                    for i in range(2):
                        if times[i][0]==' ':
                            times[i] = times[i][1:] # Remove leading spaces
                    tstart = time.strptime(times[0], "%I:%M %p")
                    tend   = time.strptime(times[1], "%I:%M %p")
                    for ig in range(len(grid)):
                        g = grid[ig]
                        if g[0]==d: # If this day
                            if g[1]>=tstart.tm_hour and g[1]<=tend.tm_hour: # If classes during this hour
                                self.avail[ig] = 0
                                
    def refreshFac(self,faculty):
        '''Filters boards based on current faculty availability'''
        for f in faculty:
            for facname in self.members:
                if f.name==facname:
                    self.avail = [self.avail[i]*f.avail[i] for i in range(len(self.avail))]
          
    
boards = []
for ib in range(len(composition)):
    b = Board(composition.loc[ib,])
    b.initTimes(grid,students)
    b.refreshFac(faculty)
    boards.append(b)

# Rearrange from those that are harder to schedule to those that are easier
niceness = [sum(b.avail) for b in boards]
ind = [i for _,i in sorted(zip(niceness,range(len(niceness))))]
ind = [j for (i,j) in sorted(zip(ind,range(len(ind))))] # Resolve duplicates
boards = [boards[i] for i in ind]

#for b in boards:
#    print(b)

# %%
# Backup, just so that the cell below could be rerun without ruining the data
bb = copy.deepcopy(boards)
bf = copy.deepcopy(faculty)

# %%
boards = copy.deepcopy(bb)
faculty = copy.deepcopy(bf)

for b in boards:
    b.refreshFac(faculty)
    temp = [i for i in range(len(b.avail)) if (b.avail[i]==1)]
    if len(temp)==0:
        print('Cannot solve the puzzle')
        break
    ig = min(temp)
    b.time = grid[ig]
    b.avail[ig] = 0
    for f in faculty:
        if f.name in b.members:
            f.book(ig)
    print('%s\t%s\t' % (dayName[grid[ig][0]],grid[ig][1]), end='')
    print(b)
    
#for b in boards:
#    print(b)
# Out:
# Mon	9	      amaaMetalnlscTaare 	Perr Jude Scal	011011111100011111111011111000000001111011111
# Mon	10	         tlnSilrnyEpto oa	Duek Kees Perr	001000011111011100000000000000000000000000000
# Mon	11	            BuiD cciurnNo	Benn Perr Khak	000011111111000111111011111111011111111000001
# Mon	9	              r CpeoatoeK	Kees Coll Robe	001011111111011100000000000000000000000000000
# Mon	11	            clhCEaylci tM	Kees Robe Coll	000000001100011111000000000000000000000000000
# Mon	13	             asldlusaiNeR	Kees Coll Perr	000001111100011100000000000000000000000000000
# Mon	14	               KaorM nese	Kees Jude Khak	000000111111011000000000000000000000000000000
# Mon	16	         eeaeujenpwe NasT	Perr Benn Jain	000000001100000001111011111111000001111011111
# Tue	11	              eGyDteelcnn	Jude Tibb Coll	000000000000011111000000000000011001111011111
# Tue	9	         aibaGuzeq slVear	Tibb Jude Khak	000000000010000111000000000000011111000011111
# Mon	15	               rzFeidnAau	Robe Jude Kees	000000011010011100000000000000000000000000000
# Mon	10	              dAceh iFdni	Khak Jude Benn	000010001000011100111011111000011100111011111
# Mon	17	              hJe lSwmeti	Coll Jude Benn	000000000010000111111011111000001111111011111
# Tue	10	             lceheUhlaMi 	Jude Tibb Khak	000000000000011111000000000000011001111011111
# Mon	13	               inraTSa aq	Khak Jude Benn	000000000000001001111011111000011111111011111
# Mon	16	                NaDoisey 	Jude Coll Kees	000000000000011111111000000000001111100011111
# Tue	15	          olaMReihreacc d	Khak Jude Benn	000000000000000011111011111000001111111011111
# Mon	17	           rhna HricaeHkn	Perr Duek Jain	000000000111000001111011111111000001111011111
# Mon	15	              novnay eMAc	Perr Benn Khak	000000000000000011111011111111011111111011111
# Tue	16	            r aencyMAielG	Kees Jude Khak	000000000000000001000000000000000000000000000
# Mon	14	             ayaNddnmroZ 	Robe Perr Duek	000000000111011111111011111111011111111011111
# Tue	13	             snolGi buiJa	Jude Kees Tibb	000000000000001001000000000000000000000000000
# Tue	14	    eipiaFhpnKoo-etlrLez 	Kees Jude Khak	000000000000000001000000000000000000000000000
# Tue	9	             bGHaayanbrmt	Robe Perr Duek	000000000011000111111011100111011100111000001
# Tue	10	               n eBnBtayr	Coll Kees Perr	000000000000001111111011111111011111111011111
# Tue	15	             iasWrllBmao 	Coll Robe Kees	000000000000000001000000000000000000000000000
# Tue	17	         zaosaTli bhmthEe	Kees Coll Khak	000000000000000000000000000000000000000000000

# %%
ind = [min([i for i in range(len(grid)) if grid[i]==b.time]) for b in boards]
ind = [j for (i,j) in sorted(zip(ind,range(len(ind))))]
boards = [boards[i] for i in ind]

for b in boards:
    printboard(b)
# Out:
#  amaaMetalnlscTaare 	    midway	Mon	9	    Perron	      Jude	    Scalzo
#          r CpeoatoeK	     final	Mon	9	   Keesing	   Collins	 Robertson
#     tlnSilrnyEpto oa	    midway	Mon	10	    Dueker	   Keesing	    Perron
#          dAceh iFdni	    midway	Mon	10	 Khakhalin	      Jude	   Bennett
#        BuiD cciurnNo	    midway	Mon	11	   Bennett	    Perron	 Khakhalin
#        clhCEaylci tM	    midway	Mon	11	   Keesing	 Robertson	   Collins
#         asldlusaiNeR	    midway	Mon	13	   Keesing	   Collins	    Perron
#           inraTSa aq	    midway	Mon	13	 Khakhalin	      Jude	   Bennett
#           KaorM nese	moderation	Mon	14	   Keesing	      Jude	 Khakhalin
#         ayaNddnmroZ 	    midway	Mon	14	 Robertson	    Perron	    Dueker
#           rzFeidnAau	     final	Mon	15	 Robertson	      Jude	   Keesing
#          novnay eMAc	    midway	Mon	15	    Perron	   Bennett	 Khakhalin
#     eeaeujenpwe NasT	    midway	Mon	16	    Perron	   Bennett	      Jain
#            NaDoisey 	     final	Mon	16	      Jude	   Collins	  Keesing
#          hJe lSwmeti	    midway	Mon	17	   Collins	      Jude	   Bennett
#       rhna HricaeHkn	    midway	Mon	17	    Perron	    Dueker	      Jain
#     aibaGuzeq slVear	     final	Tue	9	  Tibbetts	      Jude	 Khakhalin
#         bGHaayanbrmt	    midway	Tue	9	 Robertson	    Perron	    Dueker
#         lceheUhlaMi 	    midway	Tue	10	      Jude	  Tibbetts	 Khakhalin
#           n eBnBtayr	    midway	Tue	10	   Collins	  Keesing 	    Perron
#          eGyDteelcnn	    midway	Tue	11	      Jude	  Tibbetts	   Collins
#         snolGi buiJa	    midway	Tue	13	      Jude	   Keesing	  Tibbetts
# eipiaFhpnKoo-etlrLez 	moderation	Tue	14	   Keesing	      Jude	 Khakhalin
#      olaMReihreacc d	    midway	Tue	15	 Khakhalin	      Jude	   Bennett
#         iasWrllBmao 	     final	Tue	15	   Collins	 Robertson	   Keesing
#        r aencyMAielG	moderation	Tue	16	   Keesing	      Jude	 Khakhalin
#     zaosaTli bhmthEe	    midway	Tue	17	   Keesing	   Collins	 Khakhalin

# %%
#Sort by faculty:

for f in faculty:
    print()
    print(f.name)
    for b in boards:
        if f.name in b.members:
            printboard(b)
# Out:
# Jude
#  amaaMetalnlscTaare 	    midway	Mon	9	    Perron	      Jude	    Scalzo
#          dAceh iFdni	    midway	Mon	10	 Khakhalin	      Jude	   Bennett
#           inraTSa aq	    midway	Mon	13	 Khakhalin	      Jude	   Bennett
#           KaorM nese	moderation	Mon	14	   Keesing	      Jude	 Khakhalin
#           rzFeidnAau	     final	Mon	15	 Robertson	      Jude	   Keesing
#            NaDoisey 	     final	Mon	16	      Jude	   Collins	  Keesing
#          hJe lSwmeti	    midway	Mon	17	   Collins	      Jude	   Bennett
#     aibaGuzeq slVear	     final	Tue	9	  Tibbetts	      Jude	 Khakhalin
#         lceheUhlaMi 	    midway	Tue	10	      Jude	  Tibbetts	 Khakhalin
#          eGyDteelcnn	    midway	Tue	11	      Jude	  Tibbetts	   Collins
#         snolGi buiJa	    midway	Tue	13	      Jude	   Keesing	  Tibbetts
# eipiaFhpnKoo-etlrLez 	moderation	Tue	14	   Keesing	      Jude	 Khakhalin
#      olaMReihreacc d	    midway	Tue	15	 Khakhalin	      Jude	   Bennett
#        r aencyMAielG	moderation	Tue	16	   Keesing	      Jude	 Khakhalin
#
# Tibbetts
#     aibaGuzeq slVear	     final	Tue	9	  Tibbetts	      Jude	 Khakhalin
#         lceheUhlaMi 	    midway	Tue	10	      Jude	  Tibbetts	 Khakhalin
#          eGyDteelcnn	    midway	Tue	11	      Jude	  Tibbetts	   Collins
#         snolGi buiJa	    midway	Tue	13	      Jude	   Keesing	  Tibbetts
#
# Robertson
#          r CpeoatoeK	     final	Mon	9	   Keesing	   Collins	 Robertson
#        clhCEaylci tM	    midway	Mon	11	   Keesing	 Robertson	   Collins
#         ayaNddnmroZ 	    midway	Mon	14	 Robertson	    Perron	    Dueker
#           rzFeidnAau	     final	Mon	15	 Robertson	      Jude	   Keesing
#         bGHaayanbrmt	    midway	Tue	9	 Robertson	    Perron	    Dueker
#         iasWrllBmao 	     final	Tue	15	   Collins	 Robertson	   Keesing
#
# Collins
#          r CpeoatoeK	     final	Mon	9	   Keesing	   Collins	 Robertson
#        clhCEaylci tM	    midway	Mon	11	   Keesing	 Robertson	   Collins
#         asldlusaiNeR	    midway	Mon	13	   Keesing	   Collins	    Perron
#            NaDoisey 	     final	Mon	16	      Jude	   Collins	  Keesing
#          hJe lSwmeti	    midway	Mon	17	   Collins	      Jude	   Bennett
#           n eBnBtayr	    midway	Tue	10	   Collins	  Keesing 	    Perron
#          eGyDteelcnn	    midway	Tue	11	      Jude	  Tibbetts	   Collins
#         iasWrllBmao 	     final	Tue	15	   Collins	 Robertson	   Keesing
#     zaosaTli bhmthEe	    midway	Tue	17	   Keesing	   Collins	 Khakhalin
#
# Keesing
#          r CpeoatoeK	     final	Mon	9	   Keesing	   Collins	 Robertson
#     tlnSilrnyEpto oa	    midway	Mon	10	    Dueker	   Keesing	    Perron
#        clhCEaylci tM	    midway	Mon	11	   Keesing	 Robertson	   Collins
#         asldlusaiNeR	    midway	Mon	13	   Keesing	   Collins	    Perron
#           KaorM nese	moderation	Mon	14	   Keesing	      Jude	 Khakhalin
#           rzFeidnAau	     final	Mon	15	 Robertson	      Jude	   Keesing
#         snolGi buiJa	    midway	Tue	13	      Jude	   Keesing	  Tibbetts
# eipiaFhpnKoo-etlrLez 	moderation	Tue	14	   Keesing	      Jude	 Khakhalin
#         iasWrllBmao 	     final	Tue	15	   Collins	 Robertson	   Keesing
#        r aencyMAielG	moderation	Tue	16	   Keesing	      Jude	 Khakhalin
#     zaosaTli bhmthEe	    midway	Tue	17	   Keesing	   Collins	 Khakhalin
#
# Khakhalin
#          dAceh iFdni	    midway	Mon	10	 Khakhalin	      Jude	   Bennett
#        BuiD cciurnNo	    midway	Mon	11	   Bennett	    Perron	 Khakhalin
#           inraTSa aq	    midway	Mon	13	 Khakhalin	      Jude	   Bennett
#           KaorM nese	moderation	Mon	14	   Keesing	      Jude	 Khakhalin
#          novnay eMAc	    midway	Mon	15	    Perron	   Bennett	 Khakhalin
#     aibaGuzeq slVear	     final	Tue	9	  Tibbetts	      Jude	 Khakhalin
#         lceheUhlaMi 	    midway	Tue	10	      Jude	  Tibbetts	 Khakhalin
# eipiaFhpnKoo-etlrLez 	moderation	Tue	14	   Keesing	      Jude	 Khakhalin
#      olaMReihreacc d	    midway	Tue	15	 Khakhalin	      Jude	   Bennett
#        r aencyMAielG	moderation	Tue	16	   Keesing	      Jude	 Khakhalin
#     zaosaTli bhmthEe	    midway	Tue	17	   Keesing	   Collins	 Khakhalin
#
# Perron
#  amaaMetalnlscTaare 	    midway	Mon	9	    Perron	      Jude	    Scalzo
#     tlnSilrnyEpto oa	    midway	Mon	10	    Dueker	   Keesing	    Perron
#        BuiD cciurnNo	    midway	Mon	11	   Bennett	    Perron	 Khakhalin
#         asldlusaiNeR	    midway	Mon	13	   Keesing	   Collins	    Perron
#         ayaNddnmroZ 	    midway	Mon	14	 Robertson	    Perron	    Dueker
#          novnay eMAc	    midway	Mon	15	    Perron	   Bennett	 Khakhalin
#     eeaeujenpwe NasT	    midway	Mon	16	    Perron	   Bennett	      Jain
#       rhna HricaeHkn	    midway	Mon	17	    Perron	    Dueker	      Jain
#         bGHaayanbrmt	    midway	Tue	9	 Robertson	    Perron	    Dueker
#           n eBnBtayr	    midway	Tue	10	   Collins	  Keesing 	    Perron
#
# Bennett
#          dAceh iFdni	    midway	Mon	10	 Khakhalin	      Jude	   Bennett
#        BuiD cciurnNo	    midway	Mon	11	   Bennett	    Perron	 Khakhalin
#           inraTSa aq	    midway	Mon	13	 Khakhalin	      Jude	   Bennett
#          novnay eMAc	    midway	Mon	15	    Perron	   Bennett	 Khakhalin
#     eeaeujenpwe NasT	    midway	Mon	16	    Perron	   Bennett	      Jain
#          hJe lSwmeti	    midway	Mon	17	   Collins	      Jude	   Bennett
#      olaMReihreacc d	    midway	Tue	15	 Khakhalin	      Jude	   Bennett
#
# Dueker
#     tlnSilrnyEpto oa	    midway	Mon	10	    Dueker	   Keesing	    Perron
#         ayaNddnmroZ 	    midway	Mon	14	 Robertson	    Perron	    Dueker
#       rhna HricaeHkn	    midway	Mon	17	    Perron	    Dueker	      Jain
#         bGHaayanbrmt	    midway	Tue	9	 Robertson	    Perron	    Dueker
#
# Keesing
#            NaDoisey 	     final	Mon	16	      Jude	   Collins	  Keesing
#           n eBnBtayr	    midway	Tue	10	   Collins	  Keesing 	    Perron
#
# Jain
#     eeaeujenpwe NasT	    midway	Mon	16	    Perron	   Bennett	      Jain
#       rhna HricaeHkn	    midway	Mon	17	    Perron	    Dueker	      Jain
#
# Scalzo
#  amaaMetalnlscTaare 	    midway	Mon	9	    Perron	      Jude	    Scalzo
