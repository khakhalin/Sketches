# %% [markdown]
# ## Sproj Board Scheduler
#
# An attempt to write a script that would read faculty and students availability for the boards week, and then schedule all boards, accounting for their target composition, and student availability.
#
# Unfortunately some of the data used by this script (names) is sensitive, and had to be stored outside of git.

# %%
import pandas as pd
import time
import copy
import random
from IPython.display import HTML, display

# %%
hideNames = 1 # set 0 for troubleshooting, set 1 before githubbing

# %%
composition = pd.read_csv('../../sensitive_data/boards.csv')
students = pd.read_csv('../../sensitive_data/students.csv')
facultin = pd.read_csv('../../sensitive_data/faculty.csv')

# %%
# Create time grid
days = ['m','t','w','r','f']
dayName = {'m':'Mon','t':'Tue','w':'Wed','r':'Thu','f':'Fri'}

startTime = 9
endTime = 18
grid = [] # Array of tuples: day (as a letter), hour (as a 24h int number)
for d in days:
    for t in range(startTime,endTime):
        grid = grid + [(d,t)]
print(grid[:3])

facultin.time = facultin.time.apply(lambda x: max(x,startTime))
#print(facultin)
# Note that the script doesn't check times outside of start-end window, so all ins and outs should happen either
# within this window, or before the day starts (to add or remove an entire day)
# Out:
# [('m', 9), ('m', 10), ('m', 11)]

# %%
class Faculty:
    def __init__(self,name):
        self.name = name
        self.avail = []
        
    def __str__(self):
        return "%12s \t" % (self.name) + ''.join(['%d' % i for i in self.avail])
    
    def initAvail(self,grid,facultin):
        self.avail = [1]*len(grid)
        status = 1
        for ig in range(len(grid)):
            lin = facultin.loc[(facultin['name']==self.name) & 
                               (facultin['type']=='in') & 
                               (facultin['day']==grid[ig][0]) &
                               (facultin['time']==grid[ig][1])]
            if lin.shape[0]>0:
                status = 1
            lout = facultin.loc[(facultin['name']==self.name) & 
                               (facultin['type']=='out') & 
                               (facultin['day']==grid[ig][0]) &
                               (facultin['time']==grid[ig][1])]
            if lout.shape[0]>0:
                status = 0
            self.avail[ig] = status
            
    def updateAvail(self,grid,g,newVal=0):
        self.avail = [self.avail[i] if grid[i]!=g else newVal for i in range(len(self.avail))]
        
    def book(self,ig):
        self.avail[ig] = 0
        
        
faculty = []
for fn in composition['advisor'].append(composition['mem2']).append(composition['mem3']).unique():
    f = Faculty(fn)
    f.initAvail(grid,facultin)
    for d in days:
        f.updateAvail(grid,(d,12)) # Book lunch breaks
        if d=='w': # Wed is an advising day, so take it out completely
            for ih in range(1,25):
                f.updateAvail(grid,(d,ih),0)
    faculty.append(f)    

for f in faculty:
    print(f)
# Out:
#         Jude 	111011000111011000000000000000011111111011111
#     Tibbetts 	000000000111011111000000000000000000000000000
#    Robertson 	111011111111011111000000000111011111111011111
#      Collins 	111011111111011111000000000111011111111011111
#      Keesing 	111011111111011111000000000000000000000000000
#    Khakhalin 	111011111111011111000000000111011111111011111
#       Perron 	111011111111011111000000000111011111111011111
#      Bennett 	111011111111011111000000000111011111111011111
#       Dueker 	111011111111001100000000000111011111100000111
#        OHara 	111011110001001000000000000011000000000000000
#         Jain 	000000000000000100000000000000000100000000000
#       Scalzo 	000000000000001110000000000000000100011010000

# %%
class Board:
    '''Board object'''
    
    def __init__(self,stuff): # Creator
        self.student = stuff['first'] + ' ' + stuff['last']
        if hideNames:
            self.student = ''.join(random.sample(self.student.lower(),len(self.student)))
        self.members = list(stuff[['advisor','mem2','mem3']])
        self.email = stuff['email']
        self.type = stuff['type']
        self.avail = []  # Placeholder: availability grid
        self.time = []
        
    def __str__(self):
        s = "%20s" % (self.student) + '\t' 
        s += ' '.join([m[:4] for m in self.members]) + '\t' # Shortened version
        s += ''.join(['%d' % i for i in self.avail])
        return s
    
    def initTimes(self,grid,students):
        '''Sets boards initial options, based on students availability'''
        data = students.loc[students.email==self.email]
        self.avail = [1]*len(grid)
        for i in range(data.shape[0]):
            h = data.iloc[i]
            if h['class'][:3]!='BIO':
                #print('Included:',[_ for _ in data.iloc[i]])
                for d in days:
                    if not pd.isna(h[d]): # Class meets on this day
                        #print(h['class'])
                        times = h['time'].split('-') # String of two times
                        for it in range(2):
                            if times[it][0]==' ':
                                times[it] = times[it][1:] # Remove leading spaces
                        tstart = time.strptime(times[0], "%I:%M %p")
                        tend   = time.strptime(times[1], "%I:%M %p")
                        for ig in range(len(grid)):
                            g = grid[ig]
                            if g[0]==d: # If this day
                                if g[1]>=tstart.tm_hour and g[1]<=tend.tm_hour: # If classes during this hour
                                    self.avail[ig] = 0
                                
    def refreshFac(self,faculty):
        '''Filters boards based on current faculty availability'''
        for f in faculty:
            for facname in self.members:
                if f.name==facname:
                    self.avail = [self.avail[i]*f.avail[i] for i in range(len(self.avail))]
          
    
boards = []
print('Student availability:')
for ib in range(len(composition)):
    b = Board(composition.loc[ib,])
    b.initTimes(grid,students)
    print(b)
    boards.append(b)
    
for b in boards:
    b.refreshFac(faculty)
    
# Rearrange from those that are harder to schedule to those that are easier
niceness = [sum(b.avail) for b in boards]
ind = [i for _,i in sorted(zip(niceness,range(len(niceness))))]
boards = [boards[i] for i in ind]

print('\nFull Board availability:')
for b in boards:
    print(b)
# Out:
# Student availability:
#            yanosied 	Jude Coll Kees	111111111111111111111100000111111111100111111
#     glrvza easbqaeiu	Tibb Jude Khak	111111111111100111111111111111100111111111111
#          driaenu fza	Robe Jude Kees	111111111111111100111111111111111111000000011
#         biwalams rlo	Coll Robe Kees	110001111100111111110001111100001111111111111
#          ekteoa ocrp	Kees Coll Robe	111111111111111100111111111111111111000000011
#          edcnih difa	Khak Jude Benn	111111111100111100111111111100111100111111111
#          aeyvcn aonm	Perr Benn Khak	111111111100000111111111111111100111111111111
#           nyb tebrna	Coll Kees Perr	100000011110001111111111111110001111111111111
#        ucicdnornui b	Benn Perr Khak	111111111111100111111111111111100111111111111
#        emahcyicllct 	Kees Robe Coll	111100001100011111111100001111111111111111111
#     oloarienspt nytl	Duek Kees Perr	111100011111111100111111111111111111000000011
#     hoezsahbl imetta	Kees Coll Khak	111111100100111111111100001100111111111111111
#        ara bthbgmyan	Robe Perr Duek	111100011111100111111111100111100100111100001
#       rehinanhack hr	Perr Duek Jain	111100011111111111111111111111111111111111111
#          lmwetieh sj	Coll Jude Benn	111100111111100111111111111100000111111111111
#         ogabjisui ln	Jude Kees Tibb	011111111111111111011111111111111111111111111
#  laaat tnealamcmesra	Perr Jude Scal	111111111100111111111111111100111111111111111
#          chellimuaeh	Jude Tibb Khak	011100011111111111011111111111111111011111111
#        aasedlniu rsl	Kees Coll Perr	111111111100111100111111111100111111111111111
#      meradlchroci ae	Khak Jude Benn	111111111111100111111111111100000111111111111
#           irnqtasa a	Khak Jude Benn	111111111110001001111111111110001001111111111
#     pejnsaeeenaeu tw	Perr Benn Jain	111100011100111111111111111100111111111111111
#         r nnmodyaazd	Robe Perr Duek	111111111111111111111111111111111111111111111
#         nteld ecgyen	Jude Tibb Coll	110000001001111111110001111001111111111111111
#        agn acmeyirle	Kees Jude Khak	111111111111100011111111111111100001111111111
#           nomearke s	Kees Jude Khak	100111111111111000100111111111111001111111111
# khtonre-ilplfeoezia p	Kees OHar Khak	111111111000111111111111111000111111111100011
#    nbihnrtircsaci az	Duek Coll Robe	111111111111100011111111111111111111111111111
#
# Full Board availability:
#       rehinanhack hr	Perr Duek Jain	000000000000000100000000000000000100000000000
#     pejnsaeeenaeu tw	Perr Benn Jain	000000000000000100000000000000000100000000000
#     glrvza easbqaeiu	Tibb Jude Khak	000000000111000000000000000000000000000000000
#         nteld ecgyen	Jude Tibb Coll	000000000001011000000000000000000000000000000
#         ogabjisui ln	Jude Kees Tibb	000000000111011000000000000000000000000000000
#  laaat tnealamcmesra	Perr Jude Scal	000000000000001000000000000000000100011010000
#          chellimuaeh	Jude Tibb Khak	000000000111011000000000000000000000000000000
#        agn acmeyirle	Kees Jude Khak	111011000111000000000000000000000000000000000
#           nomearke s	Kees Jude Khak	100011000111011000000000000000000000000000000
# khtonre-ilplfeoezia p	Kees OHar Khak	111011110000001000000000000000000000000000000
#           nyb tebrna	Coll Kees Perr	100000011110001111000000000000000000000000000
#            yanosied 	Jude Coll Kees	111011000111011000000000000000000000000000000
#          driaenu fza	Robe Jude Kees	111011000111011000000000000000000000000000000
#        emahcyicllct 	Kees Robe Coll	111000001100011111000000000000000000000000000
#     oloarienspt nytl	Duek Kees Perr	111000011111001100000000000000000000000000000
#         biwalams rlo	Coll Robe Kees	110001111100011111000000000000000000000000000
#     hoezsahbl imetta	Kees Coll Khak	111011100100011111000000000000000000000000000
#        aasedlniu rsl	Kees Coll Perr	111011111100011100000000000000000000000000000
#          ekteoa ocrp	Kees Coll Robe	111011111111011100000000000000000000000000000
#        ara bthbgmyan	Robe Perr Duek	111000011111000100000000000111000100100000001
#          lmwetieh sj	Coll Jude Benn	111000000111000000000000000000000111111011111
#           irnqtasa a	Khak Jude Benn	111011000110001000000000000000001001111011111
#          edcnih difa	Khak Jude Benn	111011000100011000000000000000011100111011111
#      meradlchroci ae	Khak Jude Benn	111011000111000000000000000000000111111011111
#    nbihnrtircsaci az	Duek Coll Robe	111011111111000000000000000111011111100000111
#         r nnmodyaazd	Robe Perr Duek	111011111111001100000000000111011111100000111
#          aeyvcn aonm	Perr Benn Khak	111011111100000111000000000111000111111011111
#        ucicdnornui b	Benn Perr Khak	111011111111000111000000000111000111111011111

# %%
# Backup, just so that the cell below could be rerun without ruining the data
bb = copy.deepcopy(boards)
bf = copy.deepcopy(faculty)

# %%
boards = copy.deepcopy(bb)
faculty = copy.deepcopy(bf)

for b in boards:
    b.refreshFac(faculty)
    temp = [i for i in range(len(b.avail)) if (b.avail[i]==1)]
    if len(temp)==0:
        print('Cannot solve the puzzle for this board:')
        print(b)
        break
    ig = min(temp)
    b.time = grid[ig]
    b.avail[ig] = 0
    for f in faculty:
        if f.name in b.members:
            f.book(ig)
    print('%s\t%s\t' % (dayName[grid[ig][0]],grid[ig][1]), end='')
    print(b)
    
#for b in boards:
#    print(b)
# Out:
# Tue	15	      rehinanhack hr	Perr Duek Jain	000000000000000000000000000000000100000000000
# Thu	15	    pejnsaeeenaeu tw	Perr Benn Jain	000000000000000000000000000000000000000000000
# Tue	9	    glrvza easbqaeiu	Tibb Jude Khak	000000000011000000000000000000000000000000000
# Tue	11	        nteld ecgyen	Jude Tibb Coll	000000000000011000000000000000000000000000000
# Tue	10	        ogabjisui ln	Jude Kees Tibb	000000000000011000000000000000000000000000000
# Tue	14	 laaat tnealamcmesra	Perr Jude Scal	000000000000000000000000000000000000011010000
# Tue	13	         chellimuaeh	Jude Tibb Khak	000000000000000000000000000000000000000000000
# Mon	9	       agn acmeyirle	Kees Jude Khak	011011000000000000000000000000000000000000000
# Mon	13	          nomearke s	Kees Jude Khak	000001000000000000000000000000000000000000000
# Mon	10	khtonre-ilplfeoezia p	Kees OHar Khak	001001110000001000000000000000000000000000000
# Mon	16	          nyb tebrna	Coll Kees Perr	000000001100000011000000000000000000000000000
# Mon	11	           yanosied 	Jude Coll Kees	000001000000000000000000000000000000000000000
# Mon	14	         driaenu fza	Robe Jude Kees	000000000000000000000000000000000000000000000
# Mon	17	       emahcyicllct 	Kees Robe Coll	000000000100011111000000000000000000000000000
# Tue	9	    oloarienspt nytl	Duek Kees Perr	000000000001000000000000000000000000000000000
# Mon	15	        biwalams rlo	Coll Robe Kees	000000000000011111000000000000000000000000000
# Tue	14	    hoezsahbl imetta	Kees Coll Khak	000000000000000111000000000000000000000000000
# Tue	13	       aasedlniu rsl	Kees Coll Perr	000000000000000000000000000000000000000000000
# Tue	15	         ekteoa ocrp	Kees Coll Robe	000000000000000000000000000000000000000000000
# Mon	9	       ara bthbgmyan	Robe Perr Duek	011000000011000000000000000111000000100000001
# Mon	10	         lmwetieh sj	Coll Jude Benn	000000000000000000000000000000000011111011111
# Thu	14	          irnqtasa a	Khak Jude Benn	000000000000000000000000000000000001111011111
# Thu	13	         edcnih difa	Khak Jude Benn	000000000000000000000000000000000000111011111
# Thu	16	     meradlchroci ae	Khak Jude Benn	000000000000000000000000000000000001111011111
# Mon	13	   nbihnrtircsaci az	Duek Coll Robe	000000000010000000000000000111011111100000111
# Mon	10	        r nnmodyaazd	Robe Perr Duek	001000000011000000000000000111011011100000111
# Mon	11	         aeyvcn aonm	Perr Benn Khak	000001101000000011000000000111000001111011111
# Mon	14	       ucicdnornui b	Benn Perr Khak	000000101011000011000000000111000001111011111

# %%
ind = [min([i for i in range(len(grid)) if grid[i]==b.time]) for b in boards]
ind = [j for (i,j) in sorted(zip(ind,range(len(ind))))]
boards = [boards[i] for i in ind]

def printboard(b,mode="none"):
    if mode=="none":
        print("%22s\t%12s\t%s\t%d\t" % (b.student,b.type,dayName[b.time[0]],b.time[1]),end='')
        for fn in b.members:
            print("%10s\t" % (fn),end='')
        print()
    elif mode=="tabs":
        if not hideNames:
            print("%s\t%s\t%s\t%s\t%d\t" % (b.student,b.email,b.type,dayName[b.time[0]],b.time[1]),end='')
        else:
            print("%s\t%s\t%s\t%s\t%d\t" % (b.student,"nope@nope.edu",b.type,dayName[b.time[0]],b.time[1]),end='')
        for fn in b.members:
            print("%s\t" % (fn),end='')
        print()
    elif mode=="html":
        s = ''
        s += "<tr><td>%s</td><td>%s</td><td>%s %d</td><td>" % (b.student,b.type,dayName[b.time[0]],b.time[1])
        for fn in b.members:
            s += "%s " % (fn)
        s += "</td></tr>"
        display(HTML(s))

for b in boards:
    printboard(b,mode="tabs")
# Out:
# agn acmeyirle	nope@nope.edu	moderation	Mon	9	Keesing	Jude	Khakhalin
# ara bthbgmyan	nope@nope.edu	midway	Mon	9	Robertson	Perron	Dueker
# khtonre-ilplfeoezia p	nope@nope.edu	moderation	Mon	10	Keesing	OHara	Khakhalin
# lmwetieh sj	nope@nope.edu	midway	Mon	10	Collins	Jude	Bennett
# r nnmodyaazd	nope@nope.edu	midway	Mon	10	Robertson	Perron	Dueker
# yanosied 	nope@nope.edu	final	Mon	11	Jude	Collins	Keesing
# aeyvcn aonm	nope@nope.edu	midway	Mon	11	Perron	Bennett	Khakhalin
# nomearke s	nope@nope.edu	moderation	Mon	13	Keesing	Jude	Khakhalin
# nbihnrtircsaci az	nope@nope.edu	midway	Mon	13	Dueker	Collins	Robertson
# driaenu fza	nope@nope.edu	final	Mon	14	Robertson	Jude	Keesing
# ucicdnornui b	nope@nope.edu	midway	Mon	14	Bennett	Perron	Khakhalin
# biwalams rlo	nope@nope.edu	final	Mon	15	Collins	Robertson	Keesing
# nyb tebrna	nope@nope.edu	midway	Mon	16	Collins	Keesing	Perron
# emahcyicllct 	nope@nope.edu	midway	Mon	17	Keesing	Robertson	Collins
# glrvza easbqaeiu	nope@nope.edu	final	Tue	9	Tibbetts	Jude	Khakhalin
# oloarienspt nytl	nope@nope.edu	midway	Tue	9	Dueker	Keesing	Perron
# ogabjisui ln	nope@nope.edu	midway	Tue	10	Jude	Keesing	Tibbetts
# nteld ecgyen	nope@nope.edu	midway	Tue	11	Jude	Tibbetts	Collins
#  chellimuaeh	nope@nope.edu	midway	Tue	13	Jude	Tibbetts	Khakhalin
# aasedlniu rsl	nope@nope.edu	midway	Tue	13	Keesing	Collins	Perron
# laaat tnealamcmesra	nope@nope.edu	midway	Tue	14	Perron	Jude	Scalzo
# hoezsahbl imetta	nope@nope.edu	midway	Tue	14	Keesing	Collins	Khakhalin
# rehinanhack hr	nope@nope.edu	midway	Tue	15	Perron	Dueker	Jain
# ekteoa ocrp	nope@nope.edu	final	Tue	15	Keesing	Collins	Robertson
# edcnih difa	nope@nope.edu	midway	Thu	13	Khakhalin	Jude	Bennett
# irnqtasa a	nope@nope.edu	midway	Thu	14	Khakhalin	Jude	Bennett
# pejnsaeeenaeu tw	nope@nope.edu	midway	Thu	15	Perron	Bennett	Jain
# meradlchroci ae	nope@nope.edu	midway	Thu	16	Khakhalin	Jude	Bennett

# %%
#Sort by faculty:

for f in faculty:
    print()
    print(f.name)
    for b in boards:
        if f.name in b.members:
            printboard(b,mode="tabs")
# Out:
# Jude
# agn acmeyirle	nope@nope.edu	moderation	Mon	9	Keesing	Jude	Khakhalin
# lmwetieh sj	nope@nope.edu	midway	Mon	10	Collins	Jude	Bennett
# yanosied 	nope@nope.edu	final	Mon	11	Jude	Collins	Keesing
# nomearke s	nope@nope.edu	moderation	Mon	13	Keesing	Jude	Khakhalin
# driaenu fza	nope@nope.edu	final	Mon	14	Robertson	Jude	Keesing
# glrvza easbqaeiu	nope@nope.edu	final	Tue	9	Tibbetts	Jude	Khakhalin
# ogabjisui ln	nope@nope.edu	midway	Tue	10	Jude	Keesing	Tibbetts
# nteld ecgyen	nope@nope.edu	midway	Tue	11	Jude	Tibbetts	Collins
#  chellimuaeh	nope@nope.edu	midway	Tue	13	Jude	Tibbetts	Khakhalin
# laaat tnealamcmesra	nope@nope.edu	midway	Tue	14	Perron	Jude	Scalzo
# edcnih difa	nope@nope.edu	midway	Thu	13	Khakhalin	Jude	Bennett
# irnqtasa a	nope@nope.edu	midway	Thu	14	Khakhalin	Jude	Bennett
# meradlchroci ae	nope@nope.edu	midway	Thu	16	Khakhalin	Jude	Bennett
#
# Tibbetts
# glrvza easbqaeiu	nope@nope.edu	final	Tue	9	Tibbetts	Jude	Khakhalin
# ogabjisui ln	nope@nope.edu	midway	Tue	10	Jude	Keesing	Tibbetts
# nteld ecgyen	nope@nope.edu	midway	Tue	11	Jude	Tibbetts	Collins
#  chellimuaeh	nope@nope.edu	midway	Tue	13	Jude	Tibbetts	Khakhalin
#
# Robertson
# ara bthbgmyan	nope@nope.edu	midway	Mon	9	Robertson	Perron	Dueker
# r nnmodyaazd	nope@nope.edu	midway	Mon	10	Robertson	Perron	Dueker
# nbihnrtircsaci az	nope@nope.edu	midway	Mon	13	Dueker	Collins	Robertson
# driaenu fza	nope@nope.edu	final	Mon	14	Robertson	Jude	Keesing
# biwalams rlo	nope@nope.edu	final	Mon	15	Collins	Robertson	Keesing
# emahcyicllct 	nope@nope.edu	midway	Mon	17	Keesing	Robertson	Collins
# ekteoa ocrp	nope@nope.edu	final	Tue	15	Keesing	Collins	Robertson
#
# Collins
# lmwetieh sj	nope@nope.edu	midway	Mon	10	Collins	Jude	Bennett
# yanosied 	nope@nope.edu	final	Mon	11	Jude	Collins	Keesing
# nbihnrtircsaci az	nope@nope.edu	midway	Mon	13	Dueker	Collins	Robertson
# biwalams rlo	nope@nope.edu	final	Mon	15	Collins	Robertson	Keesing
# nyb tebrna	nope@nope.edu	midway	Mon	16	Collins	Keesing	Perron
# emahcyicllct 	nope@nope.edu	midway	Mon	17	Keesing	Robertson	Collins
# nteld ecgyen	nope@nope.edu	midway	Tue	11	Jude	Tibbetts	Collins
# aasedlniu rsl	nope@nope.edu	midway	Tue	13	Keesing	Collins	Perron
# hoezsahbl imetta	nope@nope.edu	midway	Tue	14	Keesing	Collins	Khakhalin
# ekteoa ocrp	nope@nope.edu	final	Tue	15	Keesing	Collins	Robertson
#
# Keesing
# agn acmeyirle	nope@nope.edu	moderation	Mon	9	Keesing	Jude	Khakhalin
# khtonre-ilplfeoezia p	nope@nope.edu	moderation	Mon	10	Keesing	OHara	Khakhalin
# yanosied 	nope@nope.edu	final	Mon	11	Jude	Collins	Keesing
# nomearke s	nope@nope.edu	moderation	Mon	13	Keesing	Jude	Khakhalin
# driaenu fza	nope@nope.edu	final	Mon	14	Robertson	Jude	Keesing
# biwalams rlo	nope@nope.edu	final	Mon	15	Collins	Robertson	Keesing
# nyb tebrna	nope@nope.edu	midway	Mon	16	Collins	Keesing	Perron
# emahcyicllct 	nope@nope.edu	midway	Mon	17	Keesing	Robertson	Collins
# oloarienspt nytl	nope@nope.edu	midway	Tue	9	Dueker	Keesing	Perron
# ogabjisui ln	nope@nope.edu	midway	Tue	10	Jude	Keesing	Tibbetts
# aasedlniu rsl	nope@nope.edu	midway	Tue	13	Keesing	Collins	Perron
# hoezsahbl imetta	nope@nope.edu	midway	Tue	14	Keesing	Collins	Khakhalin
# ekteoa ocrp	nope@nope.edu	final	Tue	15	Keesing	Collins	Robertson
#
# Khakhalin
# agn acmeyirle	nope@nope.edu	moderation	Mon	9	Keesing	Jude	Khakhalin
# khtonre-ilplfeoezia p	nope@nope.edu	moderation	Mon	10	Keesing	OHara	Khakhalin
# aeyvcn aonm	nope@nope.edu	midway	Mon	11	Perron	Bennett	Khakhalin
# nomearke s	nope@nope.edu	moderation	Mon	13	Keesing	Jude	Khakhalin
# ucicdnornui b	nope@nope.edu	midway	Mon	14	Bennett	Perron	Khakhalin
# glrvza easbqaeiu	nope@nope.edu	final	Tue	9	Tibbetts	Jude	Khakhalin
#  chellimuaeh	nope@nope.edu	midway	Tue	13	Jude	Tibbetts	Khakhalin
# hoezsahbl imetta	nope@nope.edu	midway	Tue	14	Keesing	Collins	Khakhalin
# edcnih difa	nope@nope.edu	midway	Thu	13	Khakhalin	Jude	Bennett
# irnqtasa a	nope@nope.edu	midway	Thu	14	Khakhalin	Jude	Bennett
# meradlchroci ae	nope@nope.edu	midway	Thu	16	Khakhalin	Jude	Bennett
#
# Perron
# ara bthbgmyan	nope@nope.edu	midway	Mon	9	Robertson	Perron	Dueker
# r nnmodyaazd	nope@nope.edu	midway	Mon	10	Robertson	Perron	Dueker
# aeyvcn aonm	nope@nope.edu	midway	Mon	11	Perron	Bennett	Khakhalin
# ucicdnornui b	nope@nope.edu	midway	Mon	14	Bennett	Perron	Khakhalin
# nyb tebrna	nope@nope.edu	midway	Mon	16	Collins	Keesing	Perron
# oloarienspt nytl	nope@nope.edu	midway	Tue	9	Dueker	Keesing	Perron
# aasedlniu rsl	nope@nope.edu	midway	Tue	13	Keesing	Collins	Perron
# laaat tnealamcmesra	nope@nope.edu	midway	Tue	14	Perron	Jude	Scalzo
# rehinanhack hr	nope@nope.edu	midway	Tue	15	Perron	Dueker	Jain
# pejnsaeeenaeu tw	nope@nope.edu	midway	Thu	15	Perron	Bennett	Jain
#
# Bennett
# lmwetieh sj	nope@nope.edu	midway	Mon	10	Collins	Jude	Bennett
# aeyvcn aonm	nope@nope.edu	midway	Mon	11	Perron	Bennett	Khakhalin
# ucicdnornui b	nope@nope.edu	midway	Mon	14	Bennett	Perron	Khakhalin
# edcnih difa	nope@nope.edu	midway	Thu	13	Khakhalin	Jude	Bennett
# irnqtasa a	nope@nope.edu	midway	Thu	14	Khakhalin	Jude	Bennett
# pejnsaeeenaeu tw	nope@nope.edu	midway	Thu	15	Perron	Bennett	Jain
# meradlchroci ae	nope@nope.edu	midway	Thu	16	Khakhalin	Jude	Bennett
#
# Dueker
# ara bthbgmyan	nope@nope.edu	midway	Mon	9	Robertson	Perron	Dueker
# r nnmodyaazd	nope@nope.edu	midway	Mon	10	Robertson	Perron	Dueker
# nbihnrtircsaci az	nope@nope.edu	midway	Mon	13	Dueker	Collins	Robertson
# oloarienspt nytl	nope@nope.edu	midway	Tue	9	Dueker	Keesing	Perron
# rehinanhack hr	nope@nope.edu	midway	Tue	15	Perron	Dueker	Jain
#
# OHara
# khtonre-ilplfeoezia p	nope@nope.edu	moderation	Mon	10	Keesing	OHara	Khakhalin
#
# Jain
# rehinanhack hr	nope@nope.edu	midway	Tue	15	Perron	Dueker	Jain
# pejnsaeeenaeu tw	nope@nope.edu	midway	Thu	15	Perron	Bennett	Jain
#
# Scalzo
# laaat tnealamcmesra	nope@nope.edu	midway	Tue	14	Perron	Jude	Scalzo
