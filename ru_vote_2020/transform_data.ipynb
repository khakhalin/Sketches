# %% [markdown]
# # Transform Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('results2020.txt', sep='\t')

# %%
data.head()
# Out:
#                                                 name  \
# 0  Общероссийское голосование по вопросу одобрени...
# 1  Общероссийское голосование по вопросу одобрени...
# 2  Общероссийское голосование по вопросу одобрени...
# 3  Общероссийское голосование по вопросу одобрени...
# 4  Общероссийское голосование по вопросу одобрени...
#
#                           reg           tik     uik  \
# 0  Республика Адыгея (Адыгея)  1 Адыгейская  УИК №1
# 1  Республика Адыгея (Адыгея)  1 Адыгейская  УИК №2
# 2  Республика Адыгея (Адыгея)  1 Адыгейская  УИК №3
# 3  Республика Адыгея (Адыгея)  1 Адыгейская  УИК №4
# 4  Республика Адыгея (Адыгея)  1 Адыгейская  УИК №5
#
#    Число участников голосования, включенных в список участников голосования на момент окончания голосования  \
# 0                                             2277.0
# 1                                             2694.0
# 2                                             2865.0
# 3                                             2054.0
# 4                                              714.0
#
#    Число бюллетеней, выданных участникам голосования  \
# 0                                             1925.0
# 1                                             2290.0
# 2                                             2441.0
# 3                                             1669.0
# 4                                              607.0
#
#    Число бюллетеней, содержащихся в ящиках для голосования  \
# 0                                             1925.0
# 1                                             2290.0
# 2                                             2441.0
# 3                                             1669.0
# 4                                              607.0
#
#    Число недействительных бюллетеней      ДА    НЕТ  \
# 0                                0.0  1749.0  176.0
# 1                                7.0  2117.0  166.0
# 2                               11.0  2171.0  259.0
# 3                                8.0  1381.0  280.0
# 4                                1.0   473.0  133.0
#
#                                                  url
# 0  http://www.vybory.izbirkom.ru/region/izbirkom?...
# 1  http://www.vybory.izbirkom.ru/region/izbirkom?...
# 2  http://www.vybory.izbirkom.ru/region/izbirkom?...
# 3  http://www.vybory.izbirkom.ru/region/izbirkom?...
# 4  http://www.vybory.izbirkom.ru/region/izbirkom?...

# %%
df = data.copy()
df = df.drop(['name', 'url'], axis=1)
df = df.rename(
    {'reg': 'region',
    'Число участников голосования, включенных в список участников голосования на момент окончания голосования': 'nominal',
    'Число бюллетеней, выданных участникам голосования': 'given',
    'Число бюллетеней, содержащихся в ящиках для голосования': 'received',
    'Число недействительных бюллетеней': 'damaged',
    'ДА': 'yes', 'НЕТ': 'no'},
    axis=1)

nans = df['nominal'].isna().values
print(f'Nans in nominal (to remove): {np.sum(nans)}')
df = df[:][np.logical_not(nans)]

df['uik'] = df['uik'].str[5:].astype(int)
df[['nominal', 'given', 'received', 'damaged', 'yes', 'no']] = df[
    ['nominal', 'given', 'received', 'damaged', 'yes', 'no']].astype(int)

dictionary = {' край': '', ' автономная область': '', ' область': '', ' автономный округ':'',
              'Республика ': '', ' Республика': '', 'город ':'',
              ' \(Адыгея\)': '', ' \(Татарстан\)': '', ' \(Якутия\)':'',
             ' - Кузбасс':'', ' - Югра':''}
for key,val in dictionary.items():
    df['region'] = df['region'].str.replace(key, val)

print(np.unique(df['region']))
df.head()
# Out:
# Nans in nominal (to remove): 273
# ['Адыгея' 'Алтай' 'Алтайский' 'Амурская' 'Архангельская' 'Астраханская'
#  'Башкортостан' 'Белгородская' 'Брянская' 'Бурятия' 'Владимирская'
#  'Волгоградская' 'Вологодская' 'Воронежская' 'Дагестан' 'Еврейская'
#  'Забайкальский' 'Ивановская' 'Ингушетия' 'Иркутская'
#  'Кабардино-Балкарская' 'Калининградская' 'Калмыкия' 'Калужская'
#  'Камчатский' 'Карачаево-Черкесская' 'Карелия' 'Кемеровская' 'Кировская'
#  'Коми' 'Костромская' 'Краснодарский' 'Красноярский' 'Крым' 'Курганская'
#  'Курская' 'Ленинградская' 'Липецкая' 'Магаданская' 'Марий Эл' 'Мордовия'
#  'Москва' 'Московская' 'Мурманская' 'Ненецкий' 'Нижегородская'
#  'Новгородская' 'Новосибирская' 'Омская' 'Оренбургская' 'Орловская'
#  'Пензенская' 'Пермский' 'Приморский' 'Псковская' 'Ростовская' 'Рязанская'
#  'Самарская' 'Санкт-Петербург' 'Саратовская' 'Саха' 'Сахалинская'
#  'Свердловская' 'Севастополь' 'Смоленская' 'Ставропольский' 'Тамбовская'
#  'Татарстан' 'Тверская' 'Томская' 'Тульская' 'Тыва' 'Тюменская'
#  'Удмуртская' 'Ульяновская' 'Хабаровский' 'Хакасия' 'Ханты-Мансийский'
#  'Челябинская' 'Чеченская' 'Чукотский' 'Ямало-Ненецкий' 'Ярославская']
#    region           tik  uik  nominal  given  received  damaged   yes   no
# 0  Адыгея  1 Адыгейская    1     2277   1925      1925        0  1749  176
# 1  Адыгея  1 Адыгейская    2     2694   2290      2290        7  2117  166
# 2  Адыгея  1 Адыгейская    3     2865   2441      2441       11  2171  259
# 3  Адыгея  1 Адыгейская    4     2054   1669      1669        8  1381  280
# 4  Адыгея  1 Адыгейская    5      714    607       607        1   473  133

# %%
df.to_csv('cleaned.csv', index=False)
