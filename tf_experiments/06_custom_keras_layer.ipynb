# %% [markdown]
# # Custom Keras layer
#
# Feferences:
# * On eager execution: https://www.tensorflow.org/guide/eager
# * Functional Keras model creation:
#     * https://www.tensorflow.org/guide/keras/functional
#     * https://gist.github.com/nairouz/5b65c35728d8fb8ec4206cbd4cbf9bea
# * Custom Keras layers:
#     * https://www.tensorflow.org/guide/keras/custom_layers_and_models
#     * https://www.tensorflow.org/tutorials/customization/custom_layers

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# Cook some simplistic data:
np.random.seed(0)
n_points = 120
xdata = np.random.uniform(size=(n_points,2))
ydata = 1*(np.sqrt(np.sum(np.square(xdata-np.array([0.5, 0.5])), axis=1)) < 0.3)
plt.figure(figsize=(4,4))
plt.scatter(xdata[:,0], xdata[:,1], color=np.array([0,0,0]) + ydata[:,None]*np.array([1,0,0]));

# %%
# Creating a model
